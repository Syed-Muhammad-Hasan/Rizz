# %%
import pandas as pd
import numpy as np
import glob
import json
import csv 
import calendar

# %%
Filenames = (glob.glob("*.txt"))
for i in Filenames:
    data = pd.read_csv(i, header=None ,names=['StateCodes','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], delimiter=r'\s+',  dtype={'StateCodes': str}).reset_index()
    finalDataFrame = pd.DataFrame(columns=['State', 'Year', 'Value'])
    month_name_to_num = {month: str(i).zfill(2) for i, month in enumerate(calendar.month_abbr) if i != 0}
    for index, row in data.iterrows():
        state = row['StateCodes'][:3]
        year = row['StateCodes'][-4:]
        for month in data.columns[2:]:
            month_num = month_name_to_num[month]
            finalDataFrame = pd.concat([finalDataFrame, pd.DataFrame({'State': [state], 'Year': [f"{year}-{month_num}"], 'Value': [row[month]]})], ignore_index=True)

    
    finalDataFrame.to_csv(i.split('.')[0]+'.csv', index=False)
# Out:
# C:\Users\hasan\AppData\Local\Temp\ipykernel_8472\1696998938.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   finalDataFrame = pd.concat([finalDataFrame, pd.DataFrame({'State': [state], 'Year': [f"{year}-{month_num}"], 'Value': [row[month]]})], ignore_index=True)
# C:\Users\hasan\AppData\Local\Temp\ipykernel_8472\1696998938.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   finalDataFrame = pd.concat([finalDataFrame, pd.DataFrame({'State': [state], 'Year': [f"{year}-{month_num}"], 'Value': [row[month]]})], ignore_index=True)
# C:\Users\hasan\AppData\Local\Temp\ipykernel_8472\1696998938.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   finalDataFrame = pd.concat([finalDataFrame, pd.DataFrame({'State': [state], 'Year': [f"{year}-{month_num}"], 'Value': [row[month]]})], ignore_index=True)

# %%
Filenames = (glob.glob("*.txt"))
for i in Filenames:
    finalDataFrame = pd.DataFrame(columns=['State','Year','Value')
    data = pd.read_csv(i, header=None ,names=['StateCodes','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], delimiter=r'\s+',  dtype={'StateCodes': str}).reset_index()
    finalDataFrame['State'] = data['StateCodes'].str[:3]
    finalDataFrame['Year'] = data['StateCodes'].str[-4:]
    finalDataFrame[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']] = data[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
    finalDataFrame.to_csv(i.split('.')[0]+'.csv', index=False)
# Out:
# 0        0010021895
# 1        0010021896
# 2        0010021897
# 3        0010021898
# 4        0010021899
#             ...
# 12478    3650022019
# 12479    3650022020
# 12480    3650022021
# 12481    3650022022
# 12482    3650022023
# Name: StateCodes, Length: 12483, dtype: object
# 0        001
# 1        001
# 2        001
# 3        001
# 4        001
#         ...
# 12478    365
# 12479    365
# 12480    365
# 12481    365
# 12482    365
# Name: State, Length: 12483, dtype: object
# final       State  Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct  \
# 0       001  1895  43.1  37.4  54.5  63.4  69.5  77.5  79.2  79.5  77.8  59.7
# 1       001  1896  43.5  47.7  52.5  68.0  75.9  77.4  81.2  82.2  75.9  63.2
# 2       001  1897  41.8  51.1  60.2  62.4  69.0  81.2  81.5  78.8  75.6  67.1
# 3       001  1898  49.0  46.1  59.2  58.8  74.1  80.4  80.0  78.8  75.2  61.0
# 4       001  1899  43.8  40.0  55.6  61.7  76.1  79.9  80.4  80.9  72.8  66.0
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 