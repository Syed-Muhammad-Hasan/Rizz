# %%
import pandas as pd
import numpy as np
import glob
import json
import csv 
import requests

# %%
#Get filenames from the directory for setting up the dropdown.

FullFilenames = (glob.glob("../../Dataset/*.csv"))
OnlyFilenames = []
for i in FullFilenames:
    SplitOnUnderscores = i.split('_')
    SplitOnSlash = SplitOnUnderscores[0].split('\\')
    filename = SplitOnSlash[1]
    OnlyFilenames.append(filename)
print(OnlyFilenames)
# Out:
# ['Albuquerque', 'Anaheim', 'Arlington', 'Atlanta', 'Aurora', 'Austin', 'Baltimore', 'Boston', 'Buffalo', 'CapeCoral', 'ColoradoSprings', 'Columbus', 'Dallas', 'Denver', 'DesMoines', 'Detroit', 'Durham', 'Fresno', 'GardenGrove', 'GrandRapids', 'Greensboro', 'Honolulu', 'Houston', 'HuntingtonBeach', 'Indianapolis', 'Irvine', 'Jerseycity', 'Knoxville', 'LasVegas', 'LosAngeles', 'Louisville', 'Madison', 'Miami', 'Milwaukee', 'Minneapolis', 'Nashville', 'NewOrleans', 'NewYork', 'Oakland', 'OklahomaCity', 'Ontario', 'Orlando', 'OverlandPark', 'Phoenix', 'Pittsburgh', 'Plano', 'Portland', 'Providence', 'RanchoCucamonga', 'Richmond', 'Rochester', 'Sacramento', 'SanDiego', 'SanFrancisco', 'SanJose', 'SantaRosa', 'Seattle', 'SiouxFalls', 'StLouis', 'Stockton', 'Tampa', 'WashingtonDC', 'Worcester']

# %%
# insert the names of columns you wish to extract Intresting columns are 
# the ones for which we will visualise the data. If all rows of any intresting columns have null values we will drop the data file.

IntrestingColumns = ['scientific_name','common_name','city','state'] 
print(IntrestingColumns)
# Out:
# ['scientific_name', 'common_name', 'city', 'state']

# %%
# Api Call to get the family name by scientific name
def getPlantFamily(plantName):
    url = "https://api.gbif.org/v1/species?name="+plantName
    myResponse = requests.get(url)
    Data = json.loads(myResponse.content)
    results = Data['results']
    for i in results:
        if 'family' in i:
            return i['family']

# %%
State_city_dictionary = dict()
Cities = (glob.glob("../../Dataset/*.csv"))
for city in Cities:
    data = pd.read_csv(city, usecols=IntrestingColumns) #use nrows paramter to limit the data if it consumes too much time to process
    data.dropna(how='any', inplace=True)
    
    if(not(data.empty)):
        # Extract city and state information
        city_state_info = data.iloc[0][['city', 'state']].to_dict()
        print(city_state_info['city'], city)
        if city_state_info['state'] not in State_city_dictionary:
                State_city_dictionary[city_state_info['state']] = [city_state_info['city'].replace(" ", "")]
        else:
            State_city_dictionary[city_state_info['state']].append(city_state_info['city'].replace(" ", ""))
states = list(State_city_dictionary.keys())
json_states = json.dumps(states)
with open('StatesDropdown.json', 'w') as f:
    json.dump(json_states, f)
# Out:
# Albuquerque ../../Dataset\Albuquerque_Final_2022-06-18.csv
# Anaheim ../../Dataset\Anaheim_Final_2022-06-18.csv
# Aurora ../../Dataset\Aurora_Final_2022-06-18.csv
# Austin ../../Dataset\Austin_Final_2022-06-18.csv
# Baltimore ../../Dataset\Baltimore_Final_2022-06-18.csv
# Boston ../../Dataset\Boston_Final_2022-06-18.csv
# Buffalo ../../Dataset\Buffalo_Final_2022-06-18.csv
# Cape Coral ../../Dataset\CapeCoral_Final_2022-06-18.csv
# Colorado Springs ../../Dataset\ColoradoSprings_Final_2022-06-18.csv
# Columbus ../../Dataset\Columbus_Final_2022-06-18.csv
# Dallas ../../Dataset\Dallas_Final_2022-06-18.csv
# Denver ../../Dataset\Denver_Final_2022-06-18.csv
# De Soto ../../Dataset\DesMoines_Final_2022-06-18.csv
# Detroit ../../Dataset\Detroit_Final_2022-06-18.csv
# Durham ../../Dataset\Durham_Final_2022-06-18.csv
# Fresno ../../Dataset\Fresno_Final_2022-06-18.csv
# Garden Grove ../../Dataset\GardenGrove_Final_2022-06-18.csv
# Grand Rapids ../../Dataset\GrandRapids_Final_2022-06-18.csv
# Greensboro ../../Dataset\Greensboro_Final_2022-06-18.csv
# Kailua ../../Dataset\Honolulu_Final_2022-06-18.csv
# Houston ../../Dataset\Houston_Final_2022-06-18.csv
# Huntington Beach ../../Dataset\HuntingtonBeach_Final_2022-06-18.csv
# Irvine ../../Dataset\Irvine_Final_2022-06-18.csv
# Knoxville ../../Dataset\Knoxville_Final_2022-06-18.csv
# Las Vegas ../../Dataset\LasVegas_Final_2022-06-18.csv
# Los Angeles ../../Dataset\LosAngeles_Final_2022-06-18.csv
# Louisville ../../Dataset\Louisville_Final_2022-06-18.csv
# Madison ../../Dataset\Madison_Final_2022-06-18.csv
# Miami ../../Dataset\Miami_Final_2022-06-18.csv
# Cedarburg ../../Dataset\Milwaukee_Final_2022-06-18.csv
# Nashville ../../Dataset\Nashville_Final_2022-06-18.csv
# New Orleans ../../Dataset\NewOrleans_Final_2022-06-18.csv
# New York ../../Dataset\NewYork_Final_2022-06-18.csv
# Oklahoma City ../../Dataset\OklahomaCity_Final_2022-06-18.csv
# Ontario ../../Dataset\Ontario_Final_2022-06-18.csv
# Orlando ../../Dataset\Orlando_Final_2022-06-18.csv
# Overland Park ../../Dataset\OverlandPark_Final_2022-06-18.csv
# Phoenix ../../Dataset\Phoenix_Final_2022-06-18.csv
# Pittsburgh ../../Dataset\Pittsburgh_Final_2022-06-18.csv
# Plano ../../Dataset\Plano_Final_2022-06-18.csv
# Portland ../../Dataset\Portland_Final_2022-06-18.csv
# Rancho Cucamonga ../../Dataset\RanchoCucamonga_Final_2022-06-18.csv
# Richmond ../../Dataset\Richmond_Final_2022-06-18.csv
# Rochester ../../Dataset\Rochester_Final_2022-06-18.csv
# Sacramento ../../Dataset\Sacramento_Final_2022-06-18.csv
# San Diego ../../Dataset\SanDiego_Final_2022-06-18.csv
# San Francisco ../../Dataset\SanFrancisco_Final_2022-06-18.csv
# Santa Rosa ../../Dataset\SantaRosa_Final_2022-06-18.csv
# Seattle ../../Dataset\Seattle_Final_2022-06-18.csv
# Sioux Falls ../../Dataset\SiouxFalls_Final_2022-06-18.csv
# St. Louis ../../Dataset\StLouis_Final_2022-06-18.csv
# Stockton ../../Dataset\Stockton_Final_2022-06-18.csv
# Tampa ../../Dataset\Tampa_Final_2022-06-18.csv
# Washington DC ../../Dataset\WashingtonDC_Final_2022-06-18.csv

# %%
for state, cities in State_city_dictionary.items():
    StateData = pd.DataFrame(columns=['source','target','value'])
    for city in cities:
        Filename = (glob.glob("../../Dataset/" + city + "*.csv"))
        if(city =='DeSoto'):
            Filename = (glob.glob("../../Dataset/DesMoines*.csv"))
        if(city =='Kailua'):
            Filename = (glob.glob("../../Dataset/Honolulu*.csv"))
        if(city =='Cedarburg'):
            Filename = (glob.glob("../../Dataset/Milwaukee*.csv"))
        if(city =='St.Louis'):
            Filename = (glob.glob("../../Dataset/StLouis*.csv"))
        print("city: ",city, " state: ",state," filename: ",Filename)
        data = pd.read_csv(Filename[0], usecols=IntrestingColumns) #use nrows paramter to limit the data if it consumes too much time to process
        data.dropna(how='any', inplace=True)
        
        if(not(data.empty)):
            # Group data by scientific_name and get the count
            tree_counts = data['scientific_name'].value_counts().to_dict()
    
            # Sort the dictionary by values in descending order
            sorted_tree_counts = dict(sorted(tree_counts.items(), key=lambda item: item[1], reverse=True))
    
            # Get the top 5 items
            top_5_trees = dict(list(sorted_tree_counts.items())[:5])
            
            
            family_plant_count = pd.DataFrame(columns=['source','target','value'])
            for key,value in top_5_trees.items():
                familyName = getPlantFamily(key)
                family_plant_count = pd.concat([pd.DataFrame([[familyName,key,value]], columns=family_plant_count.columns), family_plant_count], ignore_index=True)
    
            groupBySource = family_plant_count.groupby('source').agg( {"value":"sum"} ).reset_index()
            
            city_family_count = pd.DataFrame({
                'source': city,
                'target':  groupBySource['source'], 
                'value': groupBySource['value']
            })
            StateData = pd.concat([family_plant_count, StateData], ignore_index=True)
            StateData = pd.concat([city_family_count, StateData], ignore_index=True)
         
    
    StateCityDataframe = pd.DataFrame(columns=['source','target','value'])
    for city in cities:
        StateCityDataframe = pd.concat([pd.DataFrame([[state,city,1]], columns=StateCityDataframe.columns), StateCityDataframe], ignore_index=True)
    StateData = pd.concat([StateCityDataframe, StateData], ignore_index=True)
    StateData.dropna(how='any', inplace=True)       
    StateData.to_csv(state+'.csv', index = False)
# Out:
# city:  Albuquerque  state:  New Mexico  filename:  ['../../Dataset\\Albuquerque_Final_2022-06-18.csv']
# city:  Anaheim  state:  California  filename:  ['../../Dataset\\Anaheim_Final_2022-06-18.csv']
# city:  Fresno  state:  California  filename:  ['../../Dataset\\Fresno_Final_2022-06-18.csv']
# city:  GardenGrove  state:  California  filename:  ['../../Dataset\\GardenGrove_Final_2022-06-18.csv']
# city:  HuntingtonBeach  state:  California  filename:  ['../../Dataset\\HuntingtonBeach_Final_2022-06-18.csv']
# city:  Irvine  state:  California  filename:  ['../../Dataset\\Irvine_Final_2022-06-18.csv']
# city:  LosAngeles  state:  California  filename:  ['../../Dataset\\LosAngeles_Final_2022-06-18.csv']
# city:  Ontario  state:  California  filename:  ['../../Dataset\\Ontario_Final_2022-06-18.csv']
# city:  RanchoCucamonga  state:  California  filename:  ['../../Dataset\\RanchoCucamonga_Final_2022-06-18.csv']
# city:  Sacramento  state:  California  filename:  ['../../Dataset\\Sacramento_Final_2022-06-18.csv']
# city:  SanDiego  state:  California  filename:  ['../../Dataset\\SanDiego_Final_2022-06-18.csv']
# city:  SanFrancisco  state:  California  filename:  ['../../Dataset\\SanFrancisco_Final_2022-06-18.csv']
# city:  SantaRosa  state:  California  filename:  ['../../Dataset\\SantaRosa_Final_2022-06-18.csv']
# city:  Stockton  state:  California  filename:  ['../../Dataset\\Stockton_Final_2022-06-18.csv']
# city:  Aurora  state:  Colorado  filename:  ['../../Dataset\\Aurora_Final_2022-06-18.csv']
# city:  ColoradoSprings  state:  Colorado  filename:  ['../../Dataset\\ColoradoSprings_Final_2022-06-18.csv']
# city:  Denver  state:  Colorado  filename:  ['../../Dataset\\Denver_Final_2022-06-18.csv']
# city:  Austin  state:  Texas  filename:  ['../../Dataset\\Austin_Final_2022-06-18.csv']
# city:  Dallas  state:  Texas  filename:  ['../../Dataset\\Dallas_Final_2022-06-18.csv']
# city:  Houston  state:  Texas  filename:  ['../../Dataset\\Houston_Final_2022-06-18.csv']
# city:  Plano  state:  Texas  filename:  ['../../Dataset\\Plano_Final_2022-06-18.csv']
# city:  Baltimore  state:  Maryland  filename:  ['../../Dataset\\Baltimore_Final_2022-06-18.csv']
# city:  Boston  state:  Massachusetts  filename:  ['../../Dataset\\Boston_Final_2022-06-18.csv']
# city:  Buffalo  state:  New York  filename:  ['../../Dataset\\Buffalo_Final_2022-06-18.csv']
# city:  NewYork  state:  New York  filename:  ['../../Dataset\\NewYork_Final_2022-06-18.csv']
# city:  Rochester  state:  New York  filename:  ['../../Dataset\\Rochester_Final_2022-06-18.csv']
# city:  CapeCoral  state:  Florida  filename:  ['../../Dataset\\CapeCoral_Final_2022-06-18.csv']
# city:  Miami  state:  Florida  filename:  ['../../Dataset\\Miami_Final_2022-06-18.csv']
# city:  Orlando  state:  Florida  filename:  ['../../Dataset\\Orlando_Final_2022-06-18.csv']
# city:  Tampa  state:  Florida  filename:  ['../../Dataset\\Tampa_Final_2022-06-18.csv']
# city:  Columbus  state:  Ohio  filename:  ['../../Dataset\\Columbus_Final_2022-06-18.csv']
# city:  DeSoto  state:  Iowa  filename:  ['../../Dataset\\DesMoines_Final_2022-06-18.csv']
# city:  Detroit  state:  Michigan  filename:  ['../../Dataset\\Detroit_Final_2022-06-18.csv']
# city:  GrandRapids  state:  Michigan  filename:  ['../../Dataset\\GrandRapids_Final_2022-06-18.csv']
# city:  Durham  state:  North Carolina  filename:  ['../../Dataset\\Durham_Final_2022-06-18.csv']
# city:  Greensboro  state:  North Carolina  filename:  ['../../Dataset\\Greensboro_Final_2022-06-18.csv']
# city:  Kailua  state:  Hawaii  filename:  ['../../Dataset\\Honolulu_Final_2022-06-18.csv']
# city:  Knoxville  state:  Tennessee  filename:  ['../../Dataset\\Knoxville_Final_2022-06-18.csv']
# city:  Nashville  state:  Tennessee  filename:  ['../../Dataset\\Nashville_Final_2022-06-18.csv']
# city:  LasVegas  state:  Nevada  filename:  ['../../Dataset\\LasVegas_Final_2022-06-18.csv']
# city:  Louisville  state:  Kentucky  filename:  ['../../Dataset\\Louisville_Final_2022-06-18.csv']
# city:  Madison  state:  Wisconsin  filename:  ['../../Dataset\\Madison_Final_2022-06-18.csv']
# city:  Cedarburg  state:  Wisconsin  filename:  ['../../Dataset\\Milwaukee_Final_2022-06-18.csv']
# city:  NewOrleans  state:  Louisiana  filename:  ['../../Dataset\\NewOrleans_Final_2022-06-18.csv']
# city:  OklahomaCity  state:  Oklahoma  filename:  ['../../Dataset\\OklahomaCity_Final_2022-06-18.csv']
# city:  OverlandPark  state:  Kansas  filename:  ['../../Dataset\\OverlandPark_Final_2022-06-18.csv']
# city:  Phoenix  state:  Arizona  filename:  ['../../Dataset\\Phoenix_Final_2022-06-18.csv']
# city:  Pittsburgh  state:  Pennsylvania  filename:  ['../../Dataset\\Pittsburgh_Final_2022-06-18.csv']
# city:  Portland  state:  Oregon  filename:  ['../../Dataset\\Portland_Final_2022-06-18.csv']
# city:  Richmond  state:  Virginia  filename:  ['../../Dataset\\Richmond_Final_2022-06-18.csv']
# city:  Seattle  state:  Washington  filename:  ['../../Dataset\\Seattle_Final_2022-06-18.csv']
# city:  SiouxFalls  state:  South Dakota  filename:  ['../../Dataset\\SiouxFalls_Final_2022-06-18.csv']
# city:  St.Louis  state:  Missouri  filename:  ['../../Dataset\\StLouis_Final_2022-06-18.csv']
# city:  WashingtonDC  state:  District of Columbia  filename:  ['../../Dataset\\WashingtonDC_Final_2022-06-18.csv']
